# %%
# !pip install "ray[rllib]"
# Out:
# Collecting ray[rllib]
#   Downloading ray-1.13.0-cp38-cp38-manylinux2014_x86_64.whl (54.3 MB)
#      |████████████████████████████████| 54.3 MB 6.8 MB/s eta 0:00:01
# Collecting click<=8.0.4,>=7.0
#   Downloading click-8.0.4-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 5.4 MB/s  eta 0:00:01
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from ray[rllib]) (2.22.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.8/dist-packages (from ray[rllib]) (21.4.0)
# Collecting aiosignal
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting grpcio<=1.43.0,>=1.28.1
#   Downloading grpcio-1.43.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.1 MB)
#      |████████████████████████████████| 4.1 MB 36.8 MB/s eta 0:00:01
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.8/dist-packages (from ray[rllib]) (4.5.1)
# Collecting msgpack<2.0.0,>=1.0.0
#   Downloading msgpack-1.0.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (322 kB)
#      |████████████████████████████████| 322 kB 68.2 MB/s eta 0:00:01
# Collecting pyyaml
#   Downloading PyYAML-6.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (701 kB)
#      |████████████████████████████████| 701 kB 66.5 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.16; python_version < "3.9" in /usr/local/lib/python3.8/dist-packages (from ray[rllib]) (1.22.4)
# Collecting virtualenv
#   Downloading virtualenv-20.14.1-py2.py3-none-any.whl (8.8 MB)
#      |████████████████████████████████| 8.8 MB 69.8 MB/s eta 0:00:01
# Requirement already satisfied: protobuf<4.0.0,>=3.15.3 in /usr/local/lib/python3.8/dist-packages (from ray[rllib]) (3.19.4)
# Collecting frozenlist
#   Downloading frozenlist-1.3.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      |████████████████████████████████| 158 kB 71.2 MB/s eta 0:00:01
# Collecting filelock
#   Downloading filelock-3.7.1-py3-none-any.whl (10 kB)
# Collecting dm-tree; extra == "rllib"
#   Downloading dm_tree-0.1.7-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (142 kB)
#      |████████████████████████████████| 142 kB 61.0 MB/s eta 0:00:01
# Collecting tabulate; extra == "rllib"
#   Downloading tabulate-0.8.10-py3-none-any.whl (29 kB)
# Collecting scipy; extra == "rllib"
#   Downloading scipy-1.8.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (41.6 MB)
#      |████████████████████████████████| 41.6 MB 68.0 MB/s eta 0:00:01
# Collecting lz4; extra == "rllib"
#   Downloading lz4-4.0.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 65.6 MB/s eta 0:00:01
# Collecting pandas; extra == "rllib"
#   Downloading pandas-1.4.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
#      |████████████████████████████████| 11.7 MB 63.2 MB/s eta 0:00:01
# Collecting tensorboardX>=1.9; extra == "rllib"
#   Downloading tensorboardX-2.5.1-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 70.7 MB/s eta 0:00:01
# Collecting scikit-image; extra == "rllib"
#   Downloading scikit_image-0.19.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.0 MB)
#      |████████████████████████████████| 14.0 MB 70.0 MB/s eta 0:00:01
# Requirement already satisfied: matplotlib!=3.4.3; extra == "rllib" in /usr/local/lib/python3.8/dist-packages (from ray[rllib]) (3.5.2)
# Collecting gym<0.22; extra == "rllib"
#   Downloading gym-0.21.0.tar.gz (1.5 MB)
#      |████████████████████████████████| 1.5 MB 66.5 MB/s eta 0:00:01
# Requirement already satisfied: six>=1.5.2 in /usr/lib/python3/dist-packages (from grpcio<=1.43.0,>=1.28.1->ray[rllib]) (1.14.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema->ray[rllib]) (0.18.1)
# Requirement already satisfied: importlib-resources>=1.4.0; python_version < "3.9" in /usr/local/lib/python3.8/dist-packages (from jsonschema->ray[rllib]) (5.7.1)
# Collecting distlib<1,>=0.3.1
#   Downloading distlib-0.3.4-py2.py3-none-any.whl (461 kB)
#      |████████████████████████████████| 461 kB 64.6 MB/s eta 0:00:01
# Collecting platformdirs<3,>=2
#   Downloading platformdirs-2.5.2-py3-none-any.whl (14 kB)
# Collecting pytz>=2020.1
#   Downloading pytz-2022.1-py2.py3-none-any.whl (503 kB)
#      |████████████████████████████████| 503 kB 64.9 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.8/dist-packages (from pandas; extra == "rllib"->ray[rllib]) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from scikit-image; extra == "rllib"->ray[rllib]) (21.3)
# Collecting networkx>=2.2
#   Downloading networkx-2.8.4-py3-none-any.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 25.2 MB/s eta 0:00:01
# Collecting tifffile>=2019.7.26
#   Downloading tifffile-2022.5.4-py3-none-any.whl (195 kB)
#      |████████████████████████████████| 195 kB 67.9 MB/s eta 0:00:01
# Collecting imageio>=2.4.1
#   Downloading imageio-2.19.3-py3-none-any.whl (3.4 MB)
#      |████████████████████████████████| 3.4 MB 70.7 MB/s eta 0:00:01
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.8/dist-packages (from scikit-image; extra == "rllib"->ray[rllib]) (9.1.1)
# Collecting PyWavelets>=1.1.1
#   Downloading PyWavelets-1.3.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.9 MB)
#      |████████████████████████████████| 6.9 MB 69.5 MB/s eta 0:00:01
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.4.3; extra == "rllib"->ray[rllib]) (4.33.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.4.3; extra == "rllib"->ray[rllib]) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.4.3; extra == "rllib"->ray[rllib]) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.4.3; extra == "rllib"->ray[rllib]) (1.4.2)
# Collecting cloudpickle>=1.2.0
#   Downloading cloudpickle-2.1.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=1.4.0; python_version < "3.9"->jsonschema->ray[rllib]) (3.8.0)
# Building wheels for collected packages: gym
#   Building wheel for gym (setup.py) ... done
#   Created wheel for gym: filename=gym-0.21.0-py3-none-any.whl size=1616800 sha256=f9c219465e4067ba5ad391e0f815c50d88b854da4afec57e8e46aa0646fca757
#   Stored in directory: /root/.cache/pip/wheels/27/6d/b3/a3a6e10704795c9b9000f1ab2dc480dfe7bed42f5972806e73
# Successfully built gym
# Installing collected packages: click, frozenlist, aiosignal, grpcio, msgpack, pyyaml, distlib, filelock, platformdirs, virtualenv, dm-tree, tabulate, scipy, lz4, pytz, pandas, tensorboardX, networkx, tifffile, imageio, PyWavelets, scikit-image, cloudpickle, gym, ray
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.46.3
#     Uninstalling grpcio-1.46.3:
#       Successfully uninstalled grpcio-1.46.3
# Successfully installed PyWavelets-1.3.0 aiosignal-1.2.0 click-8.0.4 cloudpickle-2.1.0 distlib-0.3.4 dm-tree-0.1.7 filelock-3.7.1 frozenlist-1.3.0 grpcio-1.43.0 gym-0.21.0 imageio-2.19.3 lz4-4.0.1 msgpack-1.0.4 networkx-2.8.4 pandas-1.4.3 platformdirs-2.5.2 pytz-2022.1 pyyaml-6.0 ray-1.13.0 scikit-image-0.19.3 scipy-1.8.1 tabulate-0.8.10 tensorboardX-2.5.1 tifffile-2022.5.4 virtualenv-20.14.1
# WARNING: You are using pip version 20.2.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
# Import the RL algorithm (Trainer) we would like to use.
from ray.rllib.agents.ppo import PPOTrainer

# Configure the algorithm.
config = {
    # Environment (RLlib understands openAI gym registered strings).
    "env": "Taxi-v3",
    # Use 2 environment workers (aka "rollout workers") that parallelly
    # collect samples from their own environment clone(s).
    "num_workers": 2,
    # Change this to "framework: torch", if you are using PyTorch.
    # Also, use "framework: tf2" for tf2.x eager execution.
    "framework": "tf",
    # Tweak the default model provided automatically by RLlib,
    # given the environment's observation- and action spaces.
    "model": {
        "fcnet_hiddens": [64, 64],
        "fcnet_activation": "relu",
    },
    # Set up a separate evaluation worker set for the
    # `trainer.evaluate()` call after training (see below).
    "evaluation_num_workers": 1,
    # Only for evaluation runs, render the env.
    "evaluation_config": {
        "render_env": True,
    },
}

# Create our RLlib Trainer.
trainer = PPOTrainer(config=config)

# Run it for n training iterations. A training iteration includes
# parallel sample collection by the environment workers as well as
# loss calculation on the collected batch and a model update.
for _ in range(3):
    print(trainer.train())

# Evaluate the trained Trainer (and render each timestep to the shell's
# output).
trainer.evaluate()
# Out:
# 2022-06-24 04:19:49,325	WARNING trainer.py:2540 -- You have specified 1 evaluation workers, but your `evaluation_interval` is None! Therefore, evaluation will not occur automatically with each call to `Trainer.train()`. Instead, you will have to call `Trainer.evaluate()` manually in order to trigger an evaluation run.
# 2022-06-24 04:19:54,674	WARNING deprecation.py:46 -- DeprecationWarning: `simple_optimizer` has been deprecated. This will raise an error in the future!
# 2022-06-24 04:19:54,675	WARNING trainer.py:2540 -- You have specified 1 evaluation workers, but your `evaluation_interval` is None! Therefore, evaluation will not occur automatically with each call to `Trainer.train()`. Instead, you will have to call `Trainer.evaluate()` manually in order to trigger an evaluation run.
# 2022-06-24 04:19:54,745	WARNING util.py:65 -- Install gputil for GPU system monitoring.
# (scheduler +3m28s) Tip: use `ray status` to view detailed cluster status. To disable these messages, set RAY_SCHEDULER_EVENTS=0.
# (scheduler +3m28s) Warning: The following resource request cannot be scheduled right now: {'CPU': 1.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# {'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'default_policy': {'learner_stats': {'cur_kl_coeff': 0.20000000298023224, 'cur_lr': 4.999999873689376e-05, 'total_loss': 9.967861, 'policy_loss': 0.012734791, 'vf_loss': 9.955071, 'vf_explained_var': -8.177372e-06, 'kl': 0.0002816814, 'entropy': 1.7914801, 'entropy_coeff': 0.0, 'model': {}}, 'custom_metrics': {}, 'num_agent_steps_trained': 128.0}}, 'num_env_steps_sampled': 4000, 'num_env_steps_trained': 4000, 'num_agent_steps_sampled': 4000, 'num_agent_steps_trained': 4000}, 'sampler_results': {'episode_reward_max': -650.0, 'episode_reward_min': -893.0, 'episode_reward_mean': -784.55, 'episode_len_mean': 200.0, 'episode_media': {}, 'episodes_this_iter': 20, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [-821.0, -758.0, -740.0, -695.0, -821.0, -695.0, -776.0, -803.0, -731.0, -821.0, -866.0, -893.0, -785.0, -839.0, -812.0, -740.0, -740.0, -830.0, -875.0, -650.0], 'episode_lengths': [200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.0910879313379809, 'mean_inference_ms': 0.6729133244695096, 'mean_action_processing_ms': 0.06586447291109696, 'mean_env_wait_ms': 0.060450548174856664, 'mean_env_render_ms': 0.0}, 'off_policy_estimator': {}}, 'episode_reward_max': -650.0, 'episode_reward_min': -893.0, 'episode_reward_mean': -784.55, 'episode_len_mean': 200.0, 'episodes_this_iter': 20, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'hist_stats': {'episode_reward': [-821.0, -758.0, -740.0, -695.0, -821.0, -695.0, -776.0, -803.0, -731.0, -821.0, -866.0, -893.0, -785.0, -839.0, -812.0, -740.0, -740.0, -830.0, -875.0, -650.0], 'episode_lengths': [200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.0910879313379809, 'mean_inference_ms': 0.6729133244695096, 'mean_action_processing_ms': 0.06586447291109696, 'mean_env_wait_ms': 0.060450548174856664, 'mean_env_render_ms': 0.0}, 'off_policy_estimator': {}, 'num_healthy_workers': 2, 'num_agent_steps_sampled': 4000, 'num_agent_steps_trained': 4000, 'num_env_steps_sampled': 4000, 'num_env_steps_trained': 4000, 'num_env_steps_sampled_this_iter': 4000, 'num_env_steps_trained_this_iter': 4000, 'timesteps_total': 4000, 'agent_timesteps_total': 4000, 'timers': {'training_iteration_time_ms': 29071.116, 'load_time_ms': 0.209, 'load_throughput': 19152073.059, 'learn_time_ms': 4068.906, 'learn_throughput': 983.065, 'update_time_ms': 2.453}, 'counters': {'num_env_steps_sampled': 4000, 'num_env_steps_trained': 4000, 'num_agent_steps_sampled': 4000, 'num_agent_steps_trained': 4000}, 'done': False, 'episodes_total': 20, 'training_iteration': 1, 'trial_id': 'default', 'experiment_id': '655e09ed2ca3476480560e73b144af90', 'date': '2022-06-24_04-20-23', 'timestamp': 1656044423, 'time_this_iter_s': 29.07386326789856, 'time_total_s': 29.07386326789856, 'pid': 61, 'hostname': '40a65c9d3843', 'node_ip': '172.17.0.2', 'config': {'num_workers': 2, 'num_envs_per_worker': 1, 'create_env_on_driver': False, 'rollout_fragment_length': 200, 'batch_mode': 'truncate_episodes', 'gamma': 0.99, 'lr': 5e-05, 'train_batch_size': 4000, 'model': {'_use_default_native_models': False, '_disable_preprocessor_api': False, '_disable_action_flattening': False, 'fcnet_hiddens': [64, 64], 'fcnet_activation': 'relu', 'conv_filters': None, 'conv_activation': 'relu', 'post_fcnet_hiddens': [], 'post_fcnet_activation': 'relu', 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': False, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action': False, 'lstm_use_prev_reward': False, '_time_major': False, 'use_attention': False, 'attention_num_transformer_units': 1, 'attention_dim': 64, 'attention_num_heads': 1, 'attention_head_dim': 32, 'a ...
# {'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'default_policy': {'learner_stats': {'cur_kl_coeff': 0.10000000149011612, 'cur_lr': 4.999999873689376e-05, 'total_loss': 9.920154, 'policy_loss': -0.0015871089, 'vf_loss': 9.920728, 'vf_explained_var': -0.00021512348, 'kl': 0.010130921, 'entropy': 1.7743627, 'entropy_coeff': 0.0, 'model': {}}, 'custom_metrics': {}, 'num_agent_steps_trained': 128.0}}, 'num_env_steps_sampled': 8000, 'num_env_steps_trained': 8000, 'num_agent_steps_sampled': 8000, 'num_agent_steps_trained': 8000}, 'sampler_results': {'episode_reward_max': -455.0, 'episode_reward_min': -893.0, 'episode_reward_mean': -748.475, 'episode_len_mean': 198.5, 'episode_media': {}, 'episodes_this_iter': 20, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [-821.0, -758.0, -740.0, -695.0, -821.0, -695.0, -776.0, -803.0, -731.0, -821.0, -866.0, -893.0, -785.0, -839.0, -812.0, -740.0, -740.0, -830.0, -875.0, -650.0, -455.0, -749.0, -680.0, -686.0, -632.0, -731.0, -857.0, -713.0, -740.0, -776.0, -632.0, -785.0, -740.0, -722.0, -677.0, -812.0, -857.0, -722.0, -632.0, -650.0], 'episode_lengths': [200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 143, 200, 197, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.09159572687381559, 'mean_inference_ms': 0.6656433426106737, 'mean_action_processing_ms': 0.06564070612863467, 'mean_env_wait_ms': 0.060469692810628396, 'mean_env_render_ms': 0.0}, 'off_policy_estimator': {}}, 'episode_reward_max': -455.0, 'episode_reward_min': -893.0, 'episode_reward_mean': -748.475, 'episode_len_mean': 198.5, 'episodes_this_iter': 20, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'hist_stats': {'episode_reward': [-821.0, -758.0, -740.0, -695.0, -821.0, -695.0, -776.0, -803.0, -731.0, -821.0, -866.0, -893.0, -785.0, -839.0, -812.0, -740.0, -740.0, -830.0, -875.0, -650.0, -455.0, -749.0, -680.0, -686.0, -632.0, -731.0, -857.0, -713.0, -740.0, -776.0, -632.0, -785.0, -740.0, -722.0, -677.0, -812.0, -857.0, -722.0, -632.0, -650.0], 'episode_lengths': [200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 143, 200, 197, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.09159572687381559, 'mean_inference_ms': 0.6656433426106737, 'mean_action_processing_ms': 0.06564070612863467, 'mean_env_wait_ms': 0.060469692810628396, 'mean_env_render_ms': 0.0}, 'off_policy_estimator': {}, 'num_healthy_workers': 2, 'num_agent_steps_sampled': 8000, 'num_agent_steps_trained': 8000, 'num_env_steps_sampled': 8000, 'num_env_steps_trained': 8000, 'num_env_steps_sampled_this_iter': 4000, 'num_env_steps_trained_this_iter': 4000, 'timesteps_total': 8000, 'agent_timesteps_total': 8000, 'timers': {'training_iteration_time_ms': 17365.59, 'load_time_ms': 0.211, 'load_throughput': 18989491.794, 'learn_time_ms': 3969.427, 'learn_throughput': 1007.702, 'update_time_ms': 2.538}, 'counters': {'num_env_steps_sampled': 8000, 'num_env_steps_trained': 8000, 'num_agent_steps_sampled': 8000, 'num_agent_steps_trained': 8000}, 'done': False, 'episodes_total': 40, 'training_iteration': 2, 'trial_id': 'default', 'experiment_id': '655e09ed2ca3476480560e73b144af90', 'date': '2022-06-24_04-20-29', 'timestamp': 1656044429, 'time_this_iter_s': 5.665146827697754, 'time_total_s': 34.73901009559631, 'pid': 61, 'hostname': '40a65c9d3843', 'node_ip': '172.17.0.2', 'config': {'num_workers': 2, 'num_envs_per_worker': 1, 'create_env_on_driver': False, 'rollout_fragment_length': 200, 'batch_mode': 'truncate_episodes', 'gamma': 0.99, 'lr': 5e-05, 'train_batch_size': 4000, 'model': {'_use_default_native_models': False, '_disable_preprocessor_api': False, '_disable_action_flattening': F ...
# {'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'default_policy': {'learner_stats': {'cur_kl_coeff': 0.10000000149011612, 'cur_lr': 4.999999873689376e-05, 'total_loss': 9.88885, 'policy_loss': 0.0005867158, 'vf_loss': 9.887502, 'vf_explained_var': 0.0001642631, 'kl': 0.007625214, 'entropy': 1.7416108, 'entropy_coeff': 0.0, 'model': {}}, 'custom_metrics': {}, 'num_agent_steps_trained': 128.0}}, 'num_env_steps_sampled': 12000, 'num_env_steps_trained': 12000, 'num_agent_steps_sampled': 12000, 'num_agent_steps_trained': 12000}, 'sampler_results': {'episode_reward_max': -455.0, 'episode_reward_min': -893.0, 'episode_reward_mean': -704.85, 'episode_len_mean': 199.0, 'episode_media': {}, 'episodes_this_iter': 20, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [-821.0, -758.0, -740.0, -695.0, -821.0, -695.0, -776.0, -803.0, -731.0, -821.0, -866.0, -893.0, -785.0, -839.0, -812.0, -740.0, -740.0, -830.0, -875.0, -650.0, -455.0, -749.0, -680.0, -686.0, -632.0, -731.0, -857.0, -713.0, -740.0, -776.0, -632.0, -785.0, -740.0, -722.0, -677.0, -812.0, -857.0, -722.0, -632.0, -650.0, -668.0, -596.0, -659.0, -533.0, -587.0, -641.0, -614.0, -614.0, -524.0, -641.0, -641.0, -614.0, -641.0, -704.0, -686.0, -641.0, -515.0, -596.0, -560.0, -677.0], 'episode_lengths': [200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 143, 200, 197, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.09185508806803933, 'mean_inference_ms': 0.6615589578515074, 'mean_action_processing_ms': 0.0655456886537622, 'mean_env_wait_ms': 0.06047780729445364, 'mean_env_render_ms': 0.0}, 'off_policy_estimator': {}}, 'episode_reward_max': -455.0, 'episode_reward_min': -893.0, 'episode_reward_mean': -704.85, 'episode_len_mean': 199.0, 'episodes_this_iter': 20, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'hist_stats': {'episode_reward': [-821.0, -758.0, -740.0, -695.0, -821.0, -695.0, -776.0, -803.0, -731.0, -821.0, -866.0, -893.0, -785.0, -839.0, -812.0, -740.0, -740.0, -830.0, -875.0, -650.0, -455.0, -749.0, -680.0, -686.0, -632.0, -731.0, -857.0, -713.0, -740.0, -776.0, -632.0, -785.0, -740.0, -722.0, -677.0, -812.0, -857.0, -722.0, -632.0, -650.0, -668.0, -596.0, -659.0, -533.0, -587.0, -641.0, -614.0, -614.0, -524.0, -641.0, -641.0, -614.0, -641.0, -704.0, -686.0, -641.0, -515.0, -596.0, -560.0, -677.0], 'episode_lengths': [200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 143, 200, 197, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.09185508806803933, 'mean_inference_ms': 0.6615589578515074, 'mean_action_processing_ms': 0.0655456886537622, 'mean_env_wait_ms': 0.06047780729445364, 'mean_env_render_ms': 0.0}, 'off_policy_estimator': {}, 'num_healthy_workers': 2, 'num_agent_steps_sampled': 12000, 'num_agent_steps_trained': 12000, 'num_env_steps_sampled': 12000, 'num_env_steps_trained': 12000, 'num_env_steps_sampled_this_iter': 4000, 'num_env_steps_trained_this_iter': 4000, 'timesteps_total': 12000, 'agent_timesteps_total': 12000, 'timers': {'training_iteration_time_ms': 13466.689, 'load_time_ms': 0.212, 'load_throughput': 18886171.857, 'learn_time_ms': 3941.464, 'learn_throughput': 1014.851, 'update_time_ms': 2.434}, 'counters': {'num_env_steps_sampled': 12000, 'num_env_steps_trained': 12000, 'num_agent_steps_sampled': 12000, 'num_agent_steps_trained': 12000}, 'done': False, 'episodes_total': 60, 'training_iteration': 3, 'trial_id': 'default', 'experiment_id': '655e09ed2ca3476480560e73b ...
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (Dropoff)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (Pickup)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (West)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (Pickup)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (Dropoff)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (East)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (East)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (East)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (East)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (East)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (Dropoff)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (East)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (East)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (West)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (Dropoff)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (Pickup)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (East)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (South)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (South)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (East)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (North)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (West)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (North)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (East)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (East)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (East)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (North)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (Pickup)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (East)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (Dropoff)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (South)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (East)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (East)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (North)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (Dropoff)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (West)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (Pickup)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (West)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (East)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (West)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (South)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (South)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (West)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (North)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (Pickup)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (Pickup)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (West)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (South)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (North)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (Pickup)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (North)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (West)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (South)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (East)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (North)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (West)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (East)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (North)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (South)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (East)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (North)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (South)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (West)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (North)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (North)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (South)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (South)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (North)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (North)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (East)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (East)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (East)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (North)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (West)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (North)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (East)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (North)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (Dropoff)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (West)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (North)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (Pickup)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (West)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (West)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (Dropoff)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (West)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (West)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (West)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (South)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (South)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (Pickup)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (West)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (North)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (South)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (West)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (East)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (East)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (West)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (South)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (West)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (Dropoff)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (Dropoff)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (North)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (West)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (West)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (West)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (East)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (South)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (West)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (South)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (West)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (East)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (Dropoff)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (North)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (West)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (East)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (Dropoff)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (West)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (South)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (West)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (East)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (East)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# ...
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : :_|
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (Dropoff)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | :_: |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (West)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | :_:G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (North)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: |_: :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (West)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | :_:G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (East)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | :_: |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (South)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : |_: : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (West)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | :_: |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (East)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : |_: : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (West)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: |_: :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (North)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: |_: :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (West)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: |_: :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (Dropoff)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | :_:G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (East)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (East)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (East)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : :_|
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (South)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (North)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (East)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : :_|
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (South)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : :_|
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (East)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : :_|
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (East)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (North)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | :_:G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (West)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | :_:G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (Dropoff)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | :_: |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (South)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | :_: |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (Dropoff)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | :_: |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (Dropoff)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | :_:G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (North)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | :_:G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (North)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | :_: |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (South)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : |_: : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (West)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : |_: : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (West)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: |_: :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (North)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | :_:G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (East)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | :_:G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (Dropoff)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | :_:G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (North)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: |_: :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (West)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : |_: : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (South)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : :_: : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (South)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : |_: : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (North)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : :_: : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (South)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : :_: : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (Pickup)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : |_: : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (North)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: |_: :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (North)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: |_: :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (North)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | :_:G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (East)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | :_:G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (North)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (East)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : :_|
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (South)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | :_: |
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (West)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : :_|
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (East)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : :_|
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (East)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : :_|
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (East)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : :_|
# (RolloutWorker pid=546) | : : : : |
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (Pickup)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : :_|
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (South)
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546) |R: | : :G|
# (RolloutWorker pid=546) | : | : : |
# (RolloutWorker pid=546) | : : : :_|
# (RolloutWorker pid=546) | | : | : |
# (RolloutWorker pid=546) |Y| : |B: |
# (RolloutWorker pid=546) +---------+
# (RolloutWorker pid=546)   (Dropoff)

# %%
# !rllib train --run APEX --env CartPole-v0
# Out:
# 2022-06-24 04:24:02,991	WARNING services.py:2002 -- WARNING: The object store is using /tmp instead of /dev/shm because /dev/shm has only 67084288 bytes available. This will harm performance! You may be able to free up space by deleting files in /dev/shm. If you are inside a Docker container, you can increase /dev/shm size by passing '--shm-size=1.70gb' to 'docker run' (or add it to the run_options list in a Ray cluster config). Make sure to set this to more than 30% of available RAM.
# (scheduler +9s) Tip: use `ray status` to view detailed cluster status. To disable these messages, set RAY_SCHEDULER_EVENTS=0.
# (scheduler +9s) Error: No available node types can fulfill resource request {'CPU': 5.0, 'GPU': 1.0}. Add suitable node types to this cluster to resolve this issue.
# == Status ==
# Current time: 2022-06-24 04:24:09 (running for 00:00:05.11)
# Memory usage on this node: 4.1/7.7 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/4 CPUs, 0/1 GPUs, 0.0/3.08 GiB heap, 0.0/1.54 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_7b0ca_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 04:24:14 (running for 00:00:10.12)
# Memory usage on this node: 4.1/7.7 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/4 CPUs, 0/1 GPUs, 0.0/3.08 GiB heap, 0.0/1.54 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_7b0ca_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 04:24:19 (running for 00:00:15.13)
# Memory usage on this node: 4.1/7.7 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/4 CPUs, 0/1 GPUs, 0.0/3.08 GiB heap, 0.0/1.54 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_7b0ca_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 04:24:24 (running for 00:00:20.13)
# Memory usage on this node: 4.1/7.7 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/4 CPUs, 0/1 GPUs, 0.0/3.08 GiB heap, 0.0/1.54 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_7b0ca_00000 | PENDING  |       |
# +------------------------------+----------+-------+
