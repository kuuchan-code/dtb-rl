# %%
# !pip install "ray[rllib]"
# Out:
# Collecting ray[rllib]
#   Downloading ray-1.13.0-cp38-cp38-manylinux2014_x86_64.whl (54.3 MB)
#      |████████████████████████████████| 54.3 MB 14.5 MB/s eta 0:00:01
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from ray[rllib]) (2.22.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.8/dist-packages (from ray[rllib]) (4.4.0)
# Collecting msgpack<2.0.0,>=1.0.0
#   Downloading msgpack-1.0.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (322 kB)
#      |████████████████████████████████| 322 kB 9.0 MB/s eta 0:00:01
# Collecting filelock
#   Downloading filelock-3.7.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.8/dist-packages (from ray[rllib]) (21.4.0)
# Collecting aiosignal
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: protobuf<4.0.0,>=3.15.3 in /usr/local/lib/python3.8/dist-packages (from ray[rllib]) (3.19.4)
# Collecting pyyaml
#   Downloading PyYAML-6.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (701 kB)
#      |████████████████████████████████| 701 kB 15.8 MB/s eta 0:00:01
# Requirement already satisfied: click<=8.0.4,>=7.0 in /usr/local/lib/python3.8/dist-packages (from ray[rllib]) (8.0.3)
# Collecting virtualenv
#   Downloading virtualenv-20.14.1-py2.py3-none-any.whl (8.8 MB)
#      |████████████████████████████████| 8.8 MB 10.2 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.16; python_version < "3.9" in /usr/local/lib/python3.8/dist-packages (from ray[rllib]) (1.22.1)
# Collecting frozenlist
#   Downloading frozenlist-1.3.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      |████████████████████████████████| 158 kB 1.4 MB/s eta 0:00:01
# Requirement already satisfied: grpcio<=1.43.0,>=1.28.1 in /usr/local/lib/python3.8/dist-packages (from ray[rllib]) (1.43.0)
# Collecting tabulate; extra == "rllib"
#   Downloading tabulate-0.8.10-py3-none-any.whl (29 kB)
# Collecting lz4; extra == "rllib"
#   Downloading lz4-4.0.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 5.4 MB/s eta 0:00:01
# Collecting dm-tree; extra == "rllib"
#   Downloading dm_tree-0.1.7-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (142 kB)
#      |████████████████████████████████| 142 kB 5.7 MB/s eta 0:00:01
# Collecting tensorboardX>=1.9; extra == "rllib"
#   Downloading tensorboardX-2.5.1-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 2.6 MB/s eta 0:00:01
# Requirement already satisfied: matplotlib!=3.4.3; extra == "rllib" in /usr/local/lib/python3.8/dist-packages (from ray[rllib]) (3.5.1)
# Collecting pandas; extra == "rllib"
#   Downloading pandas-1.4.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
#      |████████████████████████████████| 11.7 MB 5.1 MB/s eta 0:00:01
# Collecting gym<0.22; extra == "rllib"
#   Downloading gym-0.21.0.tar.gz (1.5 MB)
#      |████████████████████████████████| 1.5 MB 9.6 MB/s eta 0:00:01
# Collecting scikit-image; extra == "rllib"
#   Downloading scikit_image-0.19.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.0 MB)
#      |████████████████████████████████| 14.0 MB 1.0 MB/s eta 0:00:01
# Collecting scipy; extra == "rllib"
#   Downloading scipy-1.8.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (41.6 MB)
#      |████████████████████████████████| 41.6 MB 7.0 MB/s eta 0:00:011
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema->ray[rllib]) (0.18.1)
# Requirement already satisfied: importlib-resources>=1.4.0; python_version < "3.9" in /usr/local/lib/python3.8/dist-packages (from jsonschema->ray[rllib]) (5.4.0)
# Collecting distlib<1,>=0.3.1
#   Downloading distlib-0.3.4-py2.py3-none-any.whl (461 kB)
#      |████████████████████████████████| 461 kB 4.4 MB/s eta 0:00:01
# Requirement already satisfied: six<2,>=1.9.0 in /usr/lib/python3/dist-packages (from virtualenv->ray[rllib]) (1.14.0)
# Requirement already satisfied: platformdirs<3,>=2 in /usr/local/lib/python3.8/dist-packages (from virtualenv->ray[rllib]) (2.4.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.4.3; extra == "rllib"->ray[rllib]) (3.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.4.3; extra == "rllib"->ray[rllib]) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.4.3; extra == "rllib"->ray[rllib]) (9.0.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.4.3; extra == "rllib"->ray[rllib]) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.4.3; extra == "rllib"->ray[rllib]) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.4.3; extra == "rllib"->ray[rllib]) (4.29.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.4.3; extra == "rllib"->ray[rllib]) (2.8.2)
# Collecting pytz>=2020.1
#   Downloading pytz-2022.1-py2.py3-none-any.whl (503 kB)
#      |████████████████████████████████| 503 kB 8.5 MB/s eta 0:00:01
# Collecting cloudpickle>=1.2.0
#   Downloading cloudpickle-2.1.0-py3-none-any.whl (25 kB)
# Collecting tifffile>=2019.7.26
#   Downloading tifffile-2022.5.4-py3-none-any.whl (195 kB)
#      |████████████████████████████████| 195 kB 3.4 MB/s eta 0:00:01
# Collecting networkx>=2.2
#   Downloading networkx-2.8.4-py3-none-any.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 6.7 MB/s eta 0:00:01
# Collecting imageio>=2.4.1
#   Downloading imageio-2.19.3-py3-none-any.whl (3.4 MB)
#      |████████████████████████████████| 3.4 MB 8.3 MB/s eta 0:00:01
# Collecting PyWavelets>=1.1.1
#   Downloading PyWavelets-1.3.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.9 MB)
#      |████████████████████████████████| 6.9 MB 6.6 MB/s eta 0:00:01
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=1.4.0; python_version < "3.9"->jsonschema->ray[rllib]) (3.7.0)
# Building wheels for collected packages: gym
#   Building wheel for gym (setup.py) ... done
#   Created wheel for gym: filename=gym-0.21.0-py3-none-any.whl size=1616825 sha256=71850f71e00374f9d2524c8a5a73f12f46a0a933d132baa4fdce91a6a1ef6f7e
#   Stored in directory: /root/.cache/pip/wheels/27/6d/b3/a3a6e10704795c9b9000f1ab2dc480dfe7bed42f5972806e73
# Successfully built gym
# Installing collected packages: msgpack, filelock, frozenlist, aiosignal, pyyaml, distlib, virtualenv, tabulate, lz4, dm-tree, tensorboardX, pytz, pandas, cloudpickle, gym, tifffile, scipy, networkx, imageio, PyWavelets, scikit-image, ray
# Successfully installed PyWavelets-1.3.0 aiosignal-1.2.0 cloudpickle-2.1.0 distlib-0.3.4 dm-tree-0.1.7 filelock-3.7.1 frozenlist-1.3.0 gym-0.21.0 imageio-2.19.3 lz4-4.0.1 msgpack-1.0.4 networkx-2.8.4 pandas-1.4.3 pytz-2022.1 pyyaml-6.0 ray-1.13.0 scikit-image-0.19.3 scipy-1.8.1 tabulate-0.8.10 tensorboardX-2.5.1 tifffile-2022.5.4 virtualenv-20.14.1
# WARNING: You are using pip version 20.2.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
# Import the RL algorithm (Trainer) we would like to use.
from ray.rllib.agents.ppo import PPOTrainer

# Configure the algorithm.
config = {
    # Environment (RLlib understands openAI gym registered strings).
    "env": "Taxi-v3",
    # Use 2 environment workers (aka "rollout workers") that parallelly
    # collect samples from their own environment clone(s).
    "num_workers": 2,
    # Change this to "framework: torch", if you are using PyTorch.
    # Also, use "framework: tf2" for tf2.x eager execution.
    "framework": "tf",
    # Tweak the default model provided automatically by RLlib,
    # given the environment's observation- and action spaces.
    "model": {
        "fcnet_hiddens": [64, 64],
        "fcnet_activation": "relu",
    },
    # Set up a separate evaluation worker set for the
    # `trainer.evaluate()` call after training (see below).
    "evaluation_num_workers": 1,
    # Only for evaluation runs, render the env.
    "evaluation_config": {
        "render_env": True,
    },
}

# Create our RLlib Trainer.
trainer = PPOTrainer(config=config)

# Run it for n training iterations. A training iteration includes
# parallel sample collection by the environment workers as well as
# loss calculation on the collected batch and a model update.
for _ in range(3):
    print(trainer.train())

# Evaluate the trained Trainer (and render each timestep to the shell's
# output).
trainer.evaluate()
# Out:
# 2022-06-24 14:35:08,280	WARNING trainer.py:2540 -- You have specified 1 evaluation workers, but your `evaluation_interval` is None! Therefore, evaluation will not occur automatically with each call to `Trainer.train()`. Instead, you will have to call `Trainer.evaluate()` manually in order to trigger an evaluation run.
# 2022-06-24 14:35:08,845	WARNING services.py:2002 -- WARNING: The object store is using /tmp instead of /dev/shm because /dev/shm has only 67096576 bytes available. This will harm performance! You may be able to free up space by deleting files in /dev/shm. If you are inside a Docker container, you can increase /dev/shm size by passing '--shm-size=4.71gb' to 'docker run' (or add it to the run_options list in a Ray cluster config). Make sure to set this to more than 30% of available RAM.
# 2022-06-24 14:35:16,477	WARNING deprecation.py:46 -- DeprecationWarning: `simple_optimizer` has been deprecated. This will raise an error in the future!
# 2022-06-24 14:35:16,478	WARNING trainer.py:2540 -- You have specified 1 evaluation workers, but your `evaluation_interval` is None! Therefore, evaluation will not occur automatically with each call to `Trainer.train()`. Instead, you will have to call `Trainer.evaluate()` manually in order to trigger an evaluation run.
# 2022-06-24 14:35:16,539	WARNING util.py:65 -- Install gputil for GPU system monitoring.
# 2022-06-24 14:35:17,909	WARNING deprecation.py:46 -- DeprecationWarning: `slice` has been deprecated. Use `SampleBatch[start:stop]` instead. This will raise an error in the future!
# {'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'default_policy': {'learner_stats': {'cur_kl_coeff': 0.20000000298023224, 'cur_lr': 4.999999873689376e-05, 'total_loss': 9.9577875, 'policy_loss': 0.010163003, 'vf_loss': 9.947568, 'vf_explained_var': -7.089748e-06, 'kl': 0.00028428528, 'entropy': 1.7914788, 'entropy_coeff': 0.0, 'model': {}}, 'custom_metrics': {}, 'num_agent_steps_trained': 128.0}}, 'num_env_steps_sampled': 4000, 'num_env_steps_trained': 4000, 'num_agent_steps_sampled': 4000, 'num_agent_steps_trained': 4000}, 'sampler_results': {'episode_reward_max': -381.0, 'episode_reward_min': -875.0, 'episode_reward_mean': -750.65, 'episode_len_mean': 192.95, 'episode_media': {}, 'episodes_this_iter': 20, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [-839.0, -866.0, -812.0, -875.0, -794.0, -421.0, -749.0, -381.0, -839.0, -713.0, -866.0, -740.0, -758.0, -848.0, -713.0, -722.0, -848.0, -767.0, -695.0, -767.0], 'episode_lengths': [200, 200, 200, 200, 200, 127, 200, 132, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.07522541067112928, 'mean_inference_ms': 0.4976951498082136, 'mean_action_processing_ms': 0.049505574532832455, 'mean_env_wait_ms': 0.04253805666670449, 'mean_env_render_ms': 0.0}, 'off_policy_estimator': {}}, 'episode_reward_max': -381.0, 'episode_reward_min': -875.0, 'episode_reward_mean': -750.65, 'episode_len_mean': 192.95, 'episodes_this_iter': 20, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'hist_stats': {'episode_reward': [-839.0, -866.0, -812.0, -875.0, -794.0, -421.0, -749.0, -381.0, -839.0, -713.0, -866.0, -740.0, -758.0, -848.0, -713.0, -722.0, -848.0, -767.0, -695.0, -767.0], 'episode_lengths': [200, 200, 200, 200, 200, 127, 200, 132, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.07522541067112928, 'mean_inference_ms': 0.4976951498082136, 'mean_action_processing_ms': 0.049505574532832455, 'mean_env_wait_ms': 0.04253805666670449, 'mean_env_render_ms': 0.0}, 'off_policy_estimator': {}, 'num_healthy_workers': 2, 'num_agent_steps_sampled': 4000, 'num_agent_steps_trained': 4000, 'num_env_steps_sampled': 4000, 'num_env_steps_trained': 4000, 'num_env_steps_sampled_this_iter': 4000, 'num_env_steps_trained_this_iter': 4000, 'timesteps_total': 4000, 'agent_timesteps_total': 4000, 'timers': {'training_iteration_time_ms': 3787.811, 'load_time_ms': 0.181, 'load_throughput': 22104368.906, 'learn_time_ms': 2410.777, 'learn_throughput': 1659.216, 'update_time_ms': 1.55}, 'counters': {'num_env_steps_sampled': 4000, 'num_env_steps_trained': 4000, 'num_agent_steps_sampled': 4000, 'num_agent_steps_trained': 4000}, 'done': False, 'episodes_total': 20, 'training_iteration': 1, 'trial_id': 'default', 'experiment_id': 'a1d3480efcb04cb9b2c27e3f42b06090', 'date': '2022-06-24_14-35-20', 'timestamp': 1656081320, 'time_this_iter_s': 3.7897138595581055, 'time_total_s': 3.7897138595581055, 'pid': 25, 'hostname': 'c0aa52e2ede1', 'node_ip': '172.17.0.2', 'config': {'num_workers': 2, 'num_envs_per_worker': 1, 'create_env_on_driver': False, 'rollout_fragment_length': 200, 'batch_mode': 'truncate_episodes', 'gamma': 0.99, 'lr': 5e-05, 'train_batch_size': 4000, 'model': {'_use_default_native_models': False, '_disable_preprocessor_api': False, '_disable_action_flattening': False, 'fcnet_hiddens': [64, 64], 'fcnet_activation': 'relu', 'conv_filters': None, 'conv_activation': 'relu', 'post_fcnet_hiddens': [], 'post_fcnet_activation': 'relu', 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': False, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action': False, 'lstm_use_prev_reward': False, '_time_major': False, 'use_attention': False, 'attention_num_transformer_units': 1, 'attention_dim': 64, 'attention_num_heads': 1, 'attention_head_dim': ...
# {'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'default_policy': {'learner_stats': {'cur_kl_coeff': 0.10000000149011612, 'cur_lr': 4.999999873689376e-05, 'total_loss': 9.885229, 'policy_loss': -0.0004836867, 'vf_loss': 9.884699, 'vf_explained_var': -7.707367e-05, 'kl': 0.010142962, 'entropy': 1.7744529, 'entropy_coeff': 0.0, 'model': {}}, 'custom_metrics': {}, 'num_agent_steps_trained': 128.0}}, 'num_env_steps_sampled': 8000, 'num_env_steps_trained': 8000, 'num_agent_steps_sampled': 8000, 'num_agent_steps_trained': 8000}, 'sampler_results': {'episode_reward_max': -381.0, 'episode_reward_min': -893.0, 'episode_reward_mean': -751.425, 'episode_len_mean': 195.675, 'episode_media': {}, 'episodes_this_iter': 20, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [-839.0, -866.0, -812.0, -875.0, -794.0, -421.0, -749.0, -381.0, -839.0, -713.0, -866.0, -740.0, -758.0, -848.0, -713.0, -722.0, -848.0, -767.0, -695.0, -767.0, -785.0, -695.0, -740.0, -893.0, -668.0, -812.0, -740.0, -749.0, -893.0, -731.0, -570.0, -758.0, -758.0, -731.0, -848.0, -704.0, -803.0, -668.0, -731.0, -767.0], 'episode_lengths': [200, 200, 200, 200, 200, 127, 200, 132, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 168, 200, 200, 200, 200, 200, 200, 200, 200, 200]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.07509456702689535, 'mean_inference_ms': 0.4891005498903026, 'mean_action_processing_ms': 0.04890799786295228, 'mean_env_wait_ms': 0.04214500023641072, 'mean_env_render_ms': 0.0}, 'off_policy_estimator': {}}, 'episode_reward_max': -381.0, 'episode_reward_min': -893.0, 'episode_reward_mean': -751.425, 'episode_len_mean': 195.675, 'episodes_this_iter': 20, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'hist_stats': {'episode_reward': [-839.0, -866.0, -812.0, -875.0, -794.0, -421.0, -749.0, -381.0, -839.0, -713.0, -866.0, -740.0, -758.0, -848.0, -713.0, -722.0, -848.0, -767.0, -695.0, -767.0, -785.0, -695.0, -740.0, -893.0, -668.0, -812.0, -740.0, -749.0, -893.0, -731.0, -570.0, -758.0, -758.0, -731.0, -848.0, -704.0, -803.0, -668.0, -731.0, -767.0], 'episode_lengths': [200, 200, 200, 200, 200, 127, 200, 132, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 168, 200, 200, 200, 200, 200, 200, 200, 200, 200]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.07509456702689535, 'mean_inference_ms': 0.4891005498903026, 'mean_action_processing_ms': 0.04890799786295228, 'mean_env_wait_ms': 0.04214500023641072, 'mean_env_render_ms': 0.0}, 'off_policy_estimator': {}, 'num_healthy_workers': 2, 'num_agent_steps_sampled': 8000, 'num_agent_steps_trained': 8000, 'num_env_steps_sampled': 8000, 'num_env_steps_trained': 8000, 'num_env_steps_sampled_this_iter': 4000, 'num_env_steps_trained_this_iter': 4000, 'timesteps_total': 8000, 'agent_timesteps_total': 8000, 'timers': {'training_iteration_time_ms': 3637.523, 'load_time_ms': 0.175, 'load_throughput': 22888425.648, 'learn_time_ms': 2304.518, 'learn_throughput': 1735.721, 'update_time_ms': 1.569}, 'counters': {'num_env_steps_sampled': 8000, 'num_env_steps_trained': 8000, 'num_agent_steps_sampled': 8000, 'num_agent_steps_trained': 8000}, 'done': False, 'episodes_total': 40, 'training_iteration': 2, 'trial_id': 'default', 'experiment_id': 'a1d3480efcb04cb9b2c27e3f42b06090', 'date': '2022-06-24_14-35-23', 'timestamp': 1656081323, 'time_this_iter_s': 3.4903509616851807, 'time_total_s': 7.280064821243286, 'pid': 25, 'hostname': 'c0aa52e2ede1', 'node_ip': '172.17.0.2', 'config': {'num_workers': 2, 'num_envs_per_worker': 1, 'create_env_on_driver': False, 'rollout_fragment_length': 200, 'batch_mode': 'truncate_episodes', 'gamma': 0.99, 'lr': 5e-05, 'train_batch_size': 4000, 'model': {'_use_default_native_models': False, '_disable_preprocessor_api': False, '_disable_action_flattening': ...
# {'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'default_policy': {'learner_stats': {'cur_kl_coeff': 0.10000000149011612, 'cur_lr': 4.999999873689376e-05, 'total_loss': 9.817825, 'policy_loss': -0.008557297, 'vf_loss': 9.825141, 'vf_explained_var': -8.538756e-05, 'kl': 0.012424762, 'entropy': 1.7121724, 'entropy_coeff': 0.0, 'model': {}}, 'custom_metrics': {}, 'num_agent_steps_trained': 128.0}}, 'num_env_steps_sampled': 12000, 'num_env_steps_trained': 12000, 'num_agent_steps_sampled': 12000, 'num_agent_steps_trained': 12000}, 'sampler_results': {'episode_reward_max': -381.0, 'episode_reward_min': -893.0, 'episode_reward_mean': -706.5166666666667, 'episode_len_mean': 197.11666666666667, 'episode_media': {}, 'episodes_this_iter': 20, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [-839.0, -866.0, -812.0, -875.0, -794.0, -421.0, -749.0, -381.0, -839.0, -713.0, -866.0, -740.0, -758.0, -848.0, -713.0, -722.0, -848.0, -767.0, -695.0, -767.0, -785.0, -695.0, -740.0, -893.0, -668.0, -812.0, -740.0, -749.0, -893.0, -731.0, -570.0, -758.0, -758.0, -731.0, -848.0, -704.0, -803.0, -668.0, -731.0, -767.0, -785.0, -587.0, -650.0, -632.0, -623.0, -578.0, -605.0, -650.0, -641.0, -587.0, -659.0, -686.0, -506.0, -596.0, -560.0, -659.0, -551.0, -623.0, -533.0, -623.0], 'episode_lengths': [200, 200, 200, 200, 200, 127, 200, 132, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 168, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.0750434993034987, 'mean_inference_ms': 0.4845396501050125, 'mean_action_processing_ms': 0.04860161877940553, 'mean_env_wait_ms': 0.04193667794885742, 'mean_env_render_ms': 0.0}, 'off_policy_estimator': {}}, 'episode_reward_max': -381.0, 'episode_reward_min': -893.0, 'episode_reward_mean': -706.5166666666667, 'episode_len_mean': 197.11666666666667, 'episodes_this_iter': 20, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'hist_stats': {'episode_reward': [-839.0, -866.0, -812.0, -875.0, -794.0, -421.0, -749.0, -381.0, -839.0, -713.0, -866.0, -740.0, -758.0, -848.0, -713.0, -722.0, -848.0, -767.0, -695.0, -767.0, -785.0, -695.0, -740.0, -893.0, -668.0, -812.0, -740.0, -749.0, -893.0, -731.0, -570.0, -758.0, -758.0, -731.0, -848.0, -704.0, -803.0, -668.0, -731.0, -767.0, -785.0, -587.0, -650.0, -632.0, -623.0, -578.0, -605.0, -650.0, -641.0, -587.0, -659.0, -686.0, -506.0, -596.0, -560.0, -659.0, -551.0, -623.0, -533.0, -623.0], 'episode_lengths': [200, 200, 200, 200, 200, 127, 200, 132, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 168, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.0750434993034987, 'mean_inference_ms': 0.4845396501050125, 'mean_action_processing_ms': 0.04860161877940553, 'mean_env_wait_ms': 0.04193667794885742, 'mean_env_render_ms': 0.0}, 'off_policy_estimator': {}, 'num_healthy_workers': 2, 'num_agent_steps_sampled': 12000, 'num_agent_steps_trained': 12000, 'num_env_steps_sampled': 12000, 'num_env_steps_trained': 12000, 'num_env_steps_sampled_this_iter': 4000, 'num_env_steps_trained_this_iter': 4000, 'timesteps_total': 12000, 'agent_timesteps_total': 12000, 'timers': {'training_iteration_time_ms': 3559.586, 'load_time_ms': 0.172, 'load_throughput': 23301688.889, 'learn_time_ms': 2239.468, 'learn_throughput': 1786.138, 'update_time_ms': 1.544}, 'counters': {'num_env_steps_sampled': 12000, 'num_env_steps_trained': 12000, 'num_agent_steps_sampled': 12000, 'num_agent_steps_trained': 12000}, 'done': False, 'episodes_total': 60, 'training_iteration': 3, 'trial_id': 'defa ...
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (North)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (Pickup)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (North)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (Dropoff)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (South)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (Dropoff)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (North)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (Pickup)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (North)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (North)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (North)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (South)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (Pickup)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (Pickup)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (South)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (North)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (Dropoff)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (North)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (North)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (Dropoff)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (North)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (North)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (North)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (South)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (Dropoff)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (Pickup)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (South)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (North)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (Dropoff)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (North)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (North)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (North)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (North)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (Dropoff)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (Pickup)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (North)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (South)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (North)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (North)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (South)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (North)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (Pickup)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (South)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (South)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (South)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (North)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (North)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (South)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (Dropoff)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (Pickup)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (Pickup)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (North)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (Dropoff)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# ...
#   'sampler_perf': {'mean_raw_obs_processing_ms': 0.07672439220987638,
#    'mean_inference_ms': 0.5141410220707837,
#    'mean_action_processing_ms': 0.05112766411134086,
#    'mean_env_wait_ms': 0.044433910148990736,
#    'mean_env_render_ms': 0.044851671237776405},
#   'off_policy_estimator': {},
#   'timesteps_this_iter': 0}}
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (South)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (Dropoff)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (North)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (Pickup)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (South)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (Pickup)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (North)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (North)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (Pickup)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (Dropoff)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (Dropoff)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (North)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (South)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (Pickup)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (Pickup)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (Dropoff)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (North)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (South)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (Dropoff)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (North)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (North)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|

# %%
# !rllib train --run APEX --env CartPole-v0
# Out:
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (South)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (South)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (North)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (South)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (South)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (South)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (Pickup)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (West)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (Dropoff)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613) |R: | : :G|
# (RolloutWorker pid=613) | : | : : |
# (RolloutWorker pid=613) | : : : : |
# (RolloutWorker pid=613) | | : | : |
# (RolloutWorker pid=613) |Y| : |B: |
# (RolloutWorker pid=613) +---------+
# (RolloutWorker pid=613)   (East)
# 2022-06-24 14:35:33,047	WARNING services.py:2002 -- WARNING: The object store is using /tmp instead of /dev/shm because /dev/shm has only 67096576 bytes available. This will harm performance! You may be able to free up space by deleting files in /dev/shm. If you are inside a Docker container, you can increase /dev/shm size by passing '--shm-size=3.92gb' to 'docker run' (or add it to the run_options list in a Ray cluster config). Make sure to set this to more than 30% of available RAM.
# == Status ==
# Current time: 2022-06-24 14:35:39 (running for 00:00:05.13)
# Memory usage on this node: 6.9/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
# == Status ==
# Current time: 2022-06-24 14:35:44 (running for 00:00:10.14)
# Memory usage on this node: 6.9/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:35:49 (running for 00:00:15.15)
# Memory usage on this node: 6.9/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:35:54 (running for 00:00:20.15)
# Memory usage on this node: 6.9/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:35:59 (running for 00:00:25.16)
# Memory usage on this node: 6.9/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:36:04 (running for 00:00:30.17)
# Memory usage on this node: 6.9/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:36:09 (running for 00:00:35.18)
# Memory usage on this node: 6.9/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:36:14 (running for 00:00:40.18)
# Memory usage on this node: 6.9/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:36:19 (running for 00:00:45.19)
# Memory usage on this node: 6.9/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:36:24 (running for 00:00:50.20)
# Memory usage on this node: 6.9/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:36:29 (running for 00:00:55.21)
# Memory usage on this node: 6.9/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:36:34 (running for 00:01:00.21)
# Memory usage on this node: 6.9/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:36:39 (running for 00:01:05.22)
# Memory usage on this node: 6.9/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# 2022-06-24 14:36:44,756	WARNING insufficient_resources_manager.py:128 -- Ignore this message if the cluster is autoscaling. You asked for 37.0 cpu and 1.0 gpu per trial, but the cluster only has 12.0 cpu and 1.0 gpu. Stop the tuning job and adjust the resources requested per trial (possibly via `resources_per_trial` or via `num_workers` for rllib) and/or add more resources to your Ray runtime.
# == Status ==
# Current time: 2022-06-24 14:36:44 (running for 00:01:10.23)
# Memory usage on this node: 6.9/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:36:49 (running for 00:01:15.24)
# Memory usage on this node: 6.9/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
# == Status ==
# Current time: 2022-06-24 14:36:54 (running for 00:01:20.24)
# Memory usage on this node: 6.9/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:36:59 (running for 00:01:25.25)
# Memory usage on this node: 6.9/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:37:04 (running for 00:01:30.26)
# Memory usage on this node: 6.9/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:37:09 (running for 00:01:35.27)
# Memory usage on this node: 6.9/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:37:14 (running for 00:01:40.27)
# Memory usage on this node: 6.9/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:37:19 (running for 00:01:45.28)
# Memory usage on this node: 6.9/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:37:24 (running for 00:01:50.29)
# Memory usage on this node: 6.9/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:37:29 (running for 00:01:55.30)
# Memory usage on this node: 6.9/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:37:34 (running for 00:02:00.30)
# Memory usage on this node: 6.8/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:37:39 (running for 00:02:05.31)
# Memory usage on this node: 6.8/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# 2022-06-24 14:37:44,843	WARNING insufficient_resources_manager.py:128 -- Ignore this message if the cluster is autoscaling. You asked for 37.0 cpu and 1.0 gpu per trial, but the cluster only has 12.0 cpu and 1.0 gpu. Stop the tuning job and adjust the resources requested per trial (possibly via `resources_per_trial` or via `num_workers` for rllib) and/or add more resources to your Ray runtime.
# == Status ==
# Current time: 2022-06-24 14:37:44 (running for 00:02:10.31)
# Memory usage on this node: 6.8/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:37:49 (running for 00:02:15.33)
# Memory usage on this node: 6.8/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:37:54 (running for 00:02:20.33)
# Memory usage on this node: 6.7/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:37:59 (running for 00:02:25.34)
# Memory usage on this node: 6.7/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
# == Status ==
# Current time: 2022-06-24 14:38:04 (running for 00:02:30.34)
# Memory usage on this node: 6.7/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:38:09 (running for 00:02:35.36)
# Memory usage on this node: 6.7/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:38:14 (running for 00:02:40.36)
# Memory usage on this node: 6.6/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:38:19 (running for 00:02:45.37)
# Memory usage on this node: 6.6/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:38:24 (running for 00:02:50.37)
# Memory usage on this node: 6.6/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:38:29 (running for 00:02:55.38)
# Memory usage on this node: 6.6/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:38:34 (running for 00:03:00.39)
# Memory usage on this node: 6.6/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:38:39 (running for 00:03:05.40)
# Memory usage on this node: 6.6/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# 2022-06-24 14:38:44,930	WARNING insufficient_resources_manager.py:128 -- Ignore this message if the cluster is autoscaling. You asked for 37.0 cpu and 1.0 gpu per trial, but the cluster only has 12.0 cpu and 1.0 gpu. Stop the tuning job and adjust the resources requested per trial (possibly via `resources_per_trial` or via `num_workers` for rllib) and/or add more resources to your Ray runtime.
# == Status ==
# Current time: 2022-06-24 14:38:44 (running for 00:03:10.40)
# Memory usage on this node: 6.6/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:38:49 (running for 00:03:15.41)
# Memory usage on this node: 6.6/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:38:54 (running for 00:03:20.42)
# Memory usage on this node: 6.6/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:38:59 (running for 00:03:25.43)
# Memory usage on this node: 6.6/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:39:04 (running for 00:03:30.43)
# Memory usage on this node: 6.6/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:39:09 (running for 00:03:35.44)
# Memory usage on this node: 6.6/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
# == Status ==
# Current time: 2022-06-24 14:39:14 (running for 00:03:40.45)
# Memory usage on this node: 6.6/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:39:19 (running for 00:03:45.46)
# Memory usage on this node: 6.6/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:39:24 (running for 00:03:50.46)
# Memory usage on this node: 6.7/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:39:29 (running for 00:03:55.47)
# Memory usage on this node: 6.7/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:39:35 (running for 00:04:00.47)
# Memory usage on this node: 6.6/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:39:40 (running for 00:04:05.48)
# Memory usage on this node: 6.6/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# 2022-06-24 14:39:45,017	WARNING insufficient_resources_manager.py:128 -- Ignore this message if the cluster is autoscaling. You asked for 37.0 cpu and 1.0 gpu per trial, but the cluster only has 12.0 cpu and 1.0 gpu. Stop the tuning job and adjust the resources requested per trial (possibly via `resources_per_trial` or via `num_workers` for rllib) and/or add more resources to your Ray runtime.
# == Status ==
# Current time: 2022-06-24 14:39:45 (running for 00:04:10.49)
# Memory usage on this node: 6.6/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:39:50 (running for 00:04:15.50)
# Memory usage on this node: 6.6/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:39:55 (running for 00:04:20.50)
# Memory usage on this node: 6.6/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:40:00 (running for 00:04:25.51)
# Memory usage on this node: 6.6/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:40:05 (running for 00:04:30.51)
# Memory usage on this node: 6.6/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:40:10 (running for 00:04:35.52)
# Memory usage on this node: 6.6/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:40:15 (running for 00:04:40.53)
# Memory usage on this node: 6.6/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:40:20 (running for 00:04:45.54)
# Memory usage on this node: 6.6/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
# == Status ==
# Current time: 2022-06-24 14:40:25 (running for 00:04:50.54)
# Memory usage on this node: 6.6/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:40:30 (running for 00:04:55.55)
# Memory usage on this node: 6.6/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:40:35 (running for 00:05:00.56)
# Memory usage on this node: 6.6/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:40:40 (running for 00:05:05.57)
# Memory usage on this node: 6.7/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# 2022-06-24 14:40:45,101	WARNING insufficient_resources_manager.py:128 -- Ignore this message if the cluster is autoscaling. You asked for 37.0 cpu and 1.0 gpu per trial, but the cluster only has 12.0 cpu and 1.0 gpu. Stop the tuning job and adjust the resources requested per trial (possibly via `resources_per_trial` or via `num_workers` for rllib) and/or add more resources to your Ray runtime.
# == Status ==
# Current time: 2022-06-24 14:40:45 (running for 00:05:10.57)
# Memory usage on this node: 6.7/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# == Status ==
# Current time: 2022-06-24 14:40:50 (running for 00:05:15.58)
# Memory usage on this node: 6.7/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +------------------------------+----------+-------+
# | Trial name                   | status   | loc   |
# |------------------------------+----------+-------|
# | APEX_CartPole-v0_e80f9_00000 | PENDING  |       |
# +------------------------------+----------+-------+
#
#
# ^C

# %%
# !rllib train --run DQN --env CartPole-v0
# Out:
# 2022-06-24 14:41:06,126	WARNING services.py:2002 -- WARNING: The object store is using /tmp instead of /dev/shm because /dev/shm has only 67096576 bytes available. This will harm performance! You may be able to free up space by deleting files in /dev/shm. If you are inside a Docker container, you can increase /dev/shm size by passing '--shm-size=3.92gb' to 'docker run' (or add it to the run_options list in a Ray cluster config). Make sure to set this to more than 30% of available RAM.
# 2022-06-24 14:41:07,711	ERROR syncer.py:147 -- Log sync requires rsync to be installed.
# (DQNTrainer pid=1766) 2022-06-24 14:41:10,979	INFO trainer.py:2332 -- Your framework setting is 'tf', meaning you are using static-graph mode. Set framework='tf2' to enable eager execution with tf2.x. You may also then want to set eager_tracing=True in order to reach similar execution speed as with static-graph mode.
# (DQNTrainer pid=1766) 2022-06-24 14:41:10,980	INFO simple_q.py:187 -- In multi-agent mode, policies will be optimized sequentially by the multi-GPU optimizer. Consider setting `simple_optimizer=True` if this doesn't work for you.
# (DQNTrainer pid=1766) 2022-06-24 14:41:10,980	INFO trainer.py:903 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# == Status ==
# Current time: 2022-06-24 14:41:11 (running for 00:00:04.38)
# Memory usage on this node: 6.9/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 1.0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+-----------------+
# | Trial name                  | status   | loc             |
# |-----------------------------+----------+-----------------|
# | DQN_CartPole-v0_ae85c_00000 | RUNNING  | 172.17.0.2:1766 |
# +-----------------------------+----------+-----------------+
#
#
# (DQNTrainer pid=1766) 2022-06-24 14:41:11,878	WARNING util.py:65 -- Install gputil for GPU system monitoring.
# (DQNTrainer pid=1766) 2022-06-24 14:41:11,943	WARNING deprecation.py:46 -- DeprecationWarning: `ReplayBuffer.add_batch()` has been deprecated. Use `RepayBuffer.add()` instead. This will raise an error in the future!
# (DQNTrainer pid=1766) 2022-06-24 14:41:11,956	WARNING multi_agent_prioritized_replay_buffer.py:186 -- Adding batches with column `weights` to this buffer while providing weights as a call argument to the add method results in the column being overwritten.
# (DQNTrainer pid=1766) 2022-06-24 14:41:11,956	WARNING deprecation.py:46 -- DeprecationWarning: `replay` has been deprecated. Use `sample` instead. This will raise an error in the future!
# == Status ==
# Current time: 2022-06-24 14:41:13 (running for 00:00:05.70)
# Memory usage on this node: 6.9/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 1.0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+-----------------+--------+------------------+------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc             |   iter |   total time (s) |   ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+-----------------+--------+------------------+------+----------+----------------------+----------------------+--------------------|
# | DQN_CartPole-v0_ae85c_00000 | RUNNING  | 172.17.0.2:1766 |      1 |          1.29123 | 1000 |  27.5714 |                   70 |                   10 |            27.5714 |
# +-----------------------------+----------+-----------------+--------+------------------+------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Current time: 2022-06-24 14:41:20 (running for 00:00:13.05)
# Memory usage on this node: 6.9/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 1.0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+-----------------+--------+------------------+------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc             |   iter |   total time (s) |   ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+-----------------+--------+------------------+------+----------+----------------------+----------------------+--------------------|
# | DQN_CartPole-v0_ae85c_00000 | RUNNING  | 172.17.0.2:1766 |      4 |          8.57668 | 4000 |    25.73 |                  112 |                    9 |              25.73 |
# +-----------------------------+----------+-----------------+--------+------------------+------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Current time: 2022-06-24 14:41:27 (running for 00:00:20.46)
# Memory usage on this node: 6.9/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 1.0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+-----------------+--------+------------------+------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc             |   iter |   total time (s) |   ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+-----------------+--------+------------------+------+----------+----------------------+----------------------+--------------------|
# | DQN_CartPole-v0_ae85c_00000 | RUNNING  | 172.17.0.2:1766 |      7 |           15.908 | 7000 |    47.55 |                  155 |                    9 |              47.55 |
# +-----------------------------+----------+-----------------+--------+------------------+------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Current time: 2022-06-24 14:41:35 (running for 00:00:27.85)
# Memory usage on this node: 6.9/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 1.0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc             |   iter |   total time (s) |    ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------|
# | DQN_CartPole-v0_ae85c_00000 | RUNNING  | 172.17.0.2:1766 |     10 |          23.2322 | 10000 |    72.62 |                  200 |                    9 |              72.62 |
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Current time: 2022-06-24 14:41:42 (running for 00:00:35.32)
# Memory usage on this node: 7.0/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 1.0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc             |   iter |   total time (s) |    ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------|
# | DQN_CartPole-v0_ae85c_00000 | RUNNING  | 172.17.0.2:1766 |     13 |          30.5935 | 13000 |    95.81 |                  200 |                   11 |              95.81 |
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
# == Status ==
# Current time: 2022-06-24 14:41:50 (running for 00:00:42.80)
# Memory usage on this node: 7.0/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 1.0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc             |   iter |   total time (s) |    ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------|
# | DQN_CartPole-v0_ae85c_00000 | RUNNING  | 172.17.0.2:1766 |     16 |          38.0364 | 16000 |   113.98 |                  200 |                   14 |             113.98 |
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Current time: 2022-06-24 14:41:55 (running for 00:00:47.81)
# Memory usage on this node: 7.0/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 1.0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc             |   iter |   total time (s) |    ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------|
# | DQN_CartPole-v0_ae85c_00000 | RUNNING  | 172.17.0.2:1766 |     18 |          42.9606 | 18000 |   122.46 |                  200 |                   14 |             122.46 |
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Current time: 2022-06-24 14:42:02 (running for 00:00:55.23)
# Memory usage on this node: 7.0/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 1.0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc             |   iter |   total time (s) |    ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------|
# | DQN_CartPole-v0_ae85c_00000 | RUNNING  | 172.17.0.2:1766 |     21 |           50.342 | 21000 |   133.75 |                  200 |                   51 |             133.75 |
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Current time: 2022-06-24 14:42:07 (running for 00:01:00.25)
# Memory usage on this node: 7.0/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 1.0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc             |   iter |   total time (s) |    ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------|
# | DQN_CartPole-v0_ae85c_00000 | RUNNING  | 172.17.0.2:1766 |     23 |          55.2772 | 23000 |   132.64 |                  200 |                   51 |             132.64 |
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Current time: 2022-06-24 14:42:15 (running for 00:01:07.63)
# Memory usage on this node: 7.0/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 1.0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc             |   iter |   total time (s) |    ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------|
# | DQN_CartPole-v0_ae85c_00000 | RUNNING  | 172.17.0.2:1766 |     26 |          62.6177 | 26000 |   131.78 |                  200 |                   51 |             131.78 |
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Current time: 2022-06-24 14:42:20 (running for 00:01:12.70)
# Memory usage on this node: 7.0/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 1.0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc             |   iter |   total time (s) |    ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------|
# | DQN_CartPole-v0_ae85c_00000 | RUNNING  | 172.17.0.2:1766 |     28 |          67.6029 | 28000 |   135.49 |                  200 |                   51 |             135.49 |
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Current time: 2022-06-24 14:42:25 (running for 00:01:17.76)
# Memory usage on this node: 7.0/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 1.0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc             |   iter |   total time (s) |    ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------|
# | DQN_CartPole-v0_ae85c_00000 | RUNNING  | 172.17.0.2:1766 |     30 |          72.5739 | 30000 |   131.11 |                  200 |                   51 |             131.11 |
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
# == Status ==
# Current time: 2022-06-24 14:42:30 (running for 00:01:22.85)
# Memory usage on this node: 7.0/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 1.0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc             |   iter |   total time (s) |    ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------|
# | DQN_CartPole-v0_ae85c_00000 | RUNNING  | 172.17.0.2:1766 |     32 |          77.5835 | 32000 |   134.01 |                  200 |                   70 |             134.01 |
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Current time: 2022-06-24 14:42:35 (running for 00:01:27.96)
# Memory usage on this node: 7.0/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 1.0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc             |   iter |   total time (s) |    ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------|
# | DQN_CartPole-v0_ae85c_00000 | RUNNING  | 172.17.0.2:1766 |     34 |          82.6824 | 34000 |   128.52 |                  200 |                   19 |             128.52 |
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Current time: 2022-06-24 14:42:40 (running for 00:01:33.13)
# Memory usage on this node: 7.1/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 1.0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc             |   iter |   total time (s) |    ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------|
# | DQN_CartPole-v0_ae85c_00000 | RUNNING  | 172.17.0.2:1766 |     36 |          87.7682 | 36000 |   135.16 |                  200 |                   19 |             135.16 |
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Current time: 2022-06-24 14:42:48 (running for 00:01:40.58)
# Memory usage on this node: 7.1/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 1.0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc             |   iter |   total time (s) |    ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------|
# | DQN_CartPole-v0_ae85c_00000 | RUNNING  | 172.17.0.2:1766 |     39 |          95.1763 | 39000 |   137.98 |                  200 |                   19 |             137.98 |
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Current time: 2022-06-24 14:42:53 (running for 00:01:45.66)
# Memory usage on this node: 7.1/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 1.0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc             |   iter |   total time (s) |    ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------|
# | DQN_CartPole-v0_ae85c_00000 | RUNNING  | 172.17.0.2:1766 |     41 |          100.178 | 41000 |    141.5 |                  200 |                   19 |              141.5 |
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Current time: 2022-06-24 14:43:00 (running for 00:01:53.17)
# Memory usage on this node: 7.1/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 1.0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc             |   iter |   total time (s) |    ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------|
# | DQN_CartPole-v0_ae85c_00000 | RUNNING  | 172.17.0.2:1766 |     44 |          107.644 | 44000 |   148.84 |                  200 |                   19 |             148.84 |
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Current time: 2022-06-24 14:43:05 (running for 00:01:58.23)
# Memory usage on this node: 7.1/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 1.0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc             |   iter |   total time (s) |    ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------|
# | DQN_CartPole-v0_ae85c_00000 | RUNNING  | 172.17.0.2:1766 |     46 |          112.658 | 46000 |   154.82 |                  200 |                   19 |             154.82 |
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
# == Status ==
# Current time: 2022-06-24 14:43:10 (running for 00:02:03.25)
# Memory usage on this node: 7.1/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 1.0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc             |   iter |   total time (s) |    ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------|
# | DQN_CartPole-v0_ae85c_00000 | RUNNING  | 172.17.0.2:1766 |     48 |          117.621 | 48000 |    156.5 |                  200 |                   19 |              156.5 |
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Current time: 2022-06-24 14:43:15 (running for 00:02:08.26)
# Memory usage on this node: 7.1/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 1.0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc             |   iter |   total time (s) |    ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------|
# | DQN_CartPole-v0_ae85c_00000 | RUNNING  | 172.17.0.2:1766 |     50 |          122.554 | 50000 |    152.7 |                  200 |                   33 |              152.7 |
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Current time: 2022-06-24 14:43:23 (running for 00:02:15.68)
# Memory usage on this node: 7.1/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 1.0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc             |   iter |   total time (s) |    ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------|
# | DQN_CartPole-v0_ae85c_00000 | RUNNING  | 172.17.0.2:1766 |     53 |          129.931 | 53000 |   140.76 |                  200 |                   33 |             140.76 |
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Current time: 2022-06-24 14:43:28 (running for 00:02:20.78)
# Memory usage on this node: 7.1/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 1.0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc             |   iter |   total time (s) |    ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------|
# | DQN_CartPole-v0_ae85c_00000 | RUNNING  | 172.17.0.2:1766 |     55 |          134.944 | 55000 |   124.43 |                  200 |                   16 |             124.43 |
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Current time: 2022-06-24 14:43:33 (running for 00:02:25.90)
# Memory usage on this node: 7.1/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 1.0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc             |   iter |   total time (s) |    ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------|
# | DQN_CartPole-v0_ae85c_00000 | RUNNING  | 172.17.0.2:1766 |     57 |          140.042 | 57000 |   118.96 |                  200 |                   16 |             118.96 |
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Current time: 2022-06-24 14:43:38 (running for 00:02:30.91)
# Memory usage on this node: 7.1/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 1.0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc             |   iter |   total time (s) |    ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------|
# | DQN_CartPole-v0_ae85c_00000 | RUNNING  | 172.17.0.2:1766 |     59 |          144.979 | 59000 |   113.31 |                  200 |                   16 |             113.31 |
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Current time: 2022-06-24 14:43:45 (running for 00:02:38.37)
# Memory usage on this node: 7.1/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 1.0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc             |   iter |   total time (s) |    ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------|
# | DQN_CartPole-v0_ae85c_00000 | RUNNING  | 172.17.0.2:1766 |     62 |          152.392 | 62000 |   130.23 |                  200 |                   16 |             130.23 |
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
# == Status ==
# Current time: 2022-06-24 14:43:50 (running for 00:02:43.42)
# Memory usage on this node: 7.1/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 1.0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc             |   iter |   total time (s) |    ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------|
# | DQN_CartPole-v0_ae85c_00000 | RUNNING  | 172.17.0.2:1766 |     64 |          157.362 | 64000 |   138.67 |                  200 |                   16 |             138.67 |
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Current time: 2022-06-24 14:43:55 (running for 00:02:48.43)
# Memory usage on this node: 7.1/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 1.0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc             |   iter |   total time (s) |    ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------|
# | DQN_CartPole-v0_ae85c_00000 | RUNNING  | 172.17.0.2:1766 |     66 |          162.355 | 66000 |   150.43 |                  200 |                   16 |             150.43 |
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Current time: 2022-06-24 14:44:00 (running for 00:02:53.48)
# Memory usage on this node: 7.1/15.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 1.0/12 CPUs, 0/1 GPUs, 0.0/7.12 GiB heap, 0.0/3.56 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /root/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc             |   iter |   total time (s) |    ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------|
# | DQN_CartPole-v0_ae85c_00000 | RUNNING  | 172.17.0.2:1766 |     68 |          167.321 | 68000 |   153.93 |                  200 |                   16 |             153.93 |
# +-----------------------------+----------+-----------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
#
#
# ^C
